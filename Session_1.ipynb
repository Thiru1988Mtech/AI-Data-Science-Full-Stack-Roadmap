# %%
x = 10
print(x)
xy=50
print(xy)
# Out:
# 10
# 50

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
y = 20
print(y)
# Out:
# 20

# %% [markdown]
# ### Data Types
# - Numbers: integer, Float
# - Strings
# - Boolean (True/False)
# - Complex numbers
# - Datetime
# - Nulls

# %%
# Integer
age = 30
print(type(age))
# Out:
# <class 'int'>

# %%
print("Thiru")
# Out:
# Thiru

# %%
# Float
temperature = 25.6
print(type(temperature))
# Out:
# <class 'float'>

# %%
# Strings
course = "Python for Data Science"
print(course)
# Out:
# Python for Data Science

# %%
# Boolean (True / False)
is_senior = True 
print(is_senior)
print(type(is_senior))
# Out:
# True
# <class 'bool'>

# %%
print(temperature < 50)
# Out:
# True

# %%
age = 40
print('My age is', age)
# Out:
# My age is 40

# %%
print('My age is %d' % age)
# Out:
# My age is 40

# %%
print('My age is %d and temperature today is %f' % (age, temperature))
# %d - Integer
# %f - Float
# %s - String
# Out:
# My age is 40 and temperature today is 25.600000

# %%
name = 'Kathir'
age = 40
temperature = 40
print("my name is %s , the age is %d and today's temperature is %f" % (name,age, temperature))
# Out:
# my name is Kathir , the age is 40 and today's temperature is 40.000000

# %%
x = 10
x
# Out:
# 10

# %%
x = 10
y = 40
print(x)
y
# Out:
# 10
# 40

# %%
course = 'Data science'
print(course)
# Out:
# Data science

# %%
print(course) # use ctrl + enter to run
# Out:
# Data science

# %%
x = 10
y = 0
# Name error, zero division error, syntax error
print(y / x)
# Out:
# 0.0

# %%
print('my age is %d' % (age))
# Out:
# my age is 40

# %%
x = 10
y = 20
z = 'course'
print(x)
print(y)
print(z)
# Out:
#   File "<ipython-input-62-ccca1f9335e6>", line 5
#     print('y)
#              ^
# SyntaxError: EOL while scanning string literal

# %%
print ('my temperature is %f my name is %s' % (temperature,name))
# Out:
# my temperature is 40.000000 my name is Kathir

# %% [markdown]
# ## Collections / Containers
# 1. List
# 2. Tuple
# 3. Dictionary
# 4. Set

# %% [markdown]
# ## List

# %%
cities = ['chennai', 'bangalore', 'hyderabad']
print(type(cities))
# Out:
# <class 'list'>

# %%
temperatures = [30, 20, 35]
print(type(temperatures))
# Out:
# <class 'list'>

# %%
print('No of values in cities', len(cities))
print('No of values in temperatures %d' % len(temperatures))
# Out:
# No of values in cities 3
# No of values in temperatures 3

# %%
print(cities[0]) # Access first element inside the list
print(cities[2]) # Access third element inside the list
print(cities[len(cities)-1]) # Access last element of the list
# Out:
# chennai
# hyderabad
# hyderabad

# %%
print(cities[2])
print(cities[len(cities)-1])
print(cities[-1]) # Negative Indexing
# Out:
# hyderabad
# hyderabad
# hyderabad

# %%
# Access first two values
ages = [10, 30, 50, 70]
print(ages[0:3]) # Slice first three elements
print(ages[:3]) # Slice first three elements. Shortcut
# Out:
# [10, 30, 50]
# [10, 30, 50]

# %%
ages = [10, 50, 40, 60, 55, 33]
ages[2:5]
# Out:
# [40, 60, 55]

# %%
ages
# Out:
# [10, 50, 40, 60, 55, 33]

# %%
print(ages[-3:])
# Out:
# [30, 50, 70]

# %%
cities = ['chennai', 'bangalore', 'hyderabad']
x = [cities[-1], cities[-2]]
type(x)
# Out:
# list

# %%
cities = ['chennai', 'bangalore', 'hyderabad']
cities[0] = 'mumbai' # Change a particular value based on index
cities
# Out:
# ['mumbai', 'bangalore', 'hyderabad']

# %%
cities = ['chennai', 'bangalore', 'hyderabad']
del cities[0] # Removing the element based on its index
cities
# Out:
# ['bangalore', 'hyderabad']

# %% [markdown]
# ## Tuples
# - They are similar to list
# - But they are immuatable

# %%
cities_tuples = ('chennai', 'bangalore', 'hyderabad')
type(cities_tuples)
# Out:
# tuple

# %% [markdown]
# #### Accessing elements inside tuple is same as List

# %%
print(cities_tuples[0])
print(cities_tuples[-1])
print(cities_tuples[:2])
# Out:
# chennai
# hyderabad
# ('chennai', 'bangalore')

# %%
cities_tuples[0] = 'mumbai'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-107-fdd2e2bcecb8> in <module>()
# ----> 1 cities_tuples[0] = 'mumbai'
#
# TypeError: 'tuple' object does not support item assignment

# %%
del cities_tuples[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-108-b3774c33518f> in <module>()
# ----> 1 del cities_tuples[0]
#
# TypeError: 'tuple' object doesn't support item deletion

# %% [markdown]
# ### Dictionary
# - Collection of key & value pairs

# %%
cities_temperatures = {'chennai': 32, 'bangalore': 25, 'hyderabad': 35}
cities_temperatures['hyderabad'] # Access an element's value using its key
# Out:
# 35

# %%
cities_temperatures = {'chennai': [32, 40], 'bangalore': [20, 30]}

# %%
cities_temperatures = {'chennai': {'min': 32, 'max': 40},
                       'bangalore': {'min': 20, 'max': 30}}

# %% [markdown]
# ### Set
# - Used to store unique values

# %%
cities = {'chennai', 'bangalore', 'chennai', 'hyderabad'}
print(type(cities))
print(cities)
# Out:
# <class 'set'>
# {'chennai', 'hyderabad', 'bangalore'}

# %%
cities_list = ['chennai', 'bangalore', 'hyderabad', 'chennai']
cities_tuple = ('chennai', 'bangalore', 'hyderabad', 'chennai')
cities_dict = {'chennai': 32, 'bangalore': 25, 'hyderabad': 35}
cities_set = {'chennai', 'bangalore', 'chennai', 'hyderabad'}

# %%
# append, extend, insert

# %%
set(cities_list[0:4]) # list to set
# Out:
# {'bangalore', 'chennai', 'hyderabad'}

# %% [markdown]
# ### Loops
# - For loop
# - While loop

# %%
## For loop to access every element in a list
cities = [10, 40, 50, 43]
for i in range(len(cities)):
  print(i, cities[i])
print('-----')
# Out:
# 0 10
# 1 40
# 2 50
# 3 43
# -----

# %%
for index in range(len(cities)):
  print(index, cities[index])
  print('-----')
# Out:
# 0 10
# -----
# 1 40
# -----
# 2 50
# -----
# 3 43
# -----

# %%
cities = ['chennai', 'bangalore', 'hyderabad', 'chennai']
for index in range(len(cities)):
  print(index, cities[index])
# Out:
# 0 chennai
# 1 bangalore
# 2 hyderabad
# 3 chennai

# %%
cities = ['chennai', 'bangalore', 'hyderabad', 'chennai']
for city in cities:
  print(city, len(city))
# Out:
# chennai 7
# bangalore 9
# hyderabad 9
# chennai 7

# %%
## Finding minimum value in a list manually
## Best way: min(list_name)
ages = [10, 40, 45, 5, 30]
min(ages)
# Out:
# 5

# %%
## Not optimal way
min_val = ages[0]
for age in ages:
  if age < min_val:
    min_val = age
print(min_val)
# Out:
# 5

# %%
### Exercise: Find out how many customers are having age > 20
ages = [10, 40, 45, 5, 30]

a=0
for age in ages:
 if age > 20:
   a = a + 1 # a += 1
print(a)
# Out:
# 3

# %%
k = [10,20,30,5,45]
max_value = k[0]
for c in k:
 if c > min_value:
    min_value = c
print(min_value)
# Out:
# 45

# %%
ages = [10, 40, 45, 5, 30]
counter = 0
for age in ages:
  if age > 20:
    counter += 1
print(counter)
# Out:
# 3
